# %% [markdown]
# # Basics of Python

# %% [markdown]
# # 1.   Variables

# %%
x = 2 # int

# %%
print(x)
# Out:
# 2

# %%
y = 3.0 # float
print(y)
# Out:
# 3.0

# %%
print(x + y)
print(x * y)
print(y ** x)
# Out:
# 5.0
# 6.0
# 9.0

# %%
print(y / x) # division
print(y // x) # floor division
print(y % x) # modulo operator
# Out:
# 1.5
# 1.0
# 1.0

# %% [markdown]
#   # 1.1 Number

# %% [markdown]
#   # 1.2 String

# %%
name = "Alex"
print(name)
# Out:
# Alex

# %%
course = input("What's the name of the course?")
# Out:
# What's the name of the course?Data Science

# %%
print(course)
# Out:
# Data Science

# %%
print("The course is " + course + ".")
# Out:
# The course is Data Science.

# %%
course.find("i")
# Out:
# 7

# %%
birth_year = input("What's the birth year?")
# Out:
# What's the birth year?2000

# %%
age = 2022 - float(birth_year)
print(age)
# Out:
# 22.0

# %% [markdown]
#   # 1.3 Boolean

# %%
is_person = False
print(is_person)
# Out:
# False

# %%
print(int(is_person))
# Out:
# 0

# %%
print(int(not is_person))
# Out:
# 1

# %%
print(x < y)
# Out:
# True

# %%
# logical operators: ==, !=, <=, etc.

# %% [markdown]
# # 2. If Statement

# %%
temp = 15
if temp > 30:
  print("It's a hot day")
elif temp > 20:
  print("It's a nice day")
elif temp > 10:
  print("It's a bit cold")
else: 
  print("It's a cold day")
# Out:
# It's a bit cold

# %% [markdown]
# # 3. Loop

# %%
for i in range(5): # for loop
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
i = 0
while i < 5: # while loop
  print(i)
  i += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # 4. Important Structures

# %% [markdown]
#   # 4.1 list

# %%
classes = ['machine learning', "inference", "probability"]

# %%
print(classes[0])
# Out:
# machine learning

# %%
print(classes[-1])
# Out:
# probability

# %%
classes[0] = "python"
print(classes)
# Out:
# ['python', 'inference', 'probability']

# %%
classes.append("regression")
print(classes)
# Out:
# ['python', 'inference', 'probability', 'regression']

# %%
classes.insert(1, "math")
print(classes)
# Out:
# ['python', 'math', 'inference', 'probability', 'regression']

# %%
numbers = range(5, 10, 2)
for i in numbers:
  print(i)
# Out:
# 5
# 7
# 9

# %% [markdown]
#   # 4.2 dictionary

# %%
customer = {
    "name": "John Smith",
    "age": 30,
    "is_verified": True
}

# %%
print(customer["age"])
customer["name"] = "Jack Smith"
print(customer)
# Out:
# 30
# {'name': 'Jack Smith', 'age': 30, 'is_verified': True}

# %% [markdown]
# # 4.3 Tuple

# %%
numbers = (1, 2, 3, 4) # does not support item assignment

# %%
print(numbers)
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# # 5. Libraries

# %%
import numpy

# %%
import numpy as np
from numpy import shape

# %%
a = np.array([[1, 2], [3, 4]])

# %%
print(a.shape)
# Out:
# (2, 2)

# %%
print(shape(a))
# Out:
# (2, 2)

# %% [markdown]
# # FAQ about Scikit-learn
#
#
# 1. What is sklearn?
#   *   It's an open source python library for predictive data analysis.
#   *   It handles basic ML algorithms like clustering, linear and logistic regressions, regression, classification, and others.
#
# 2. https://scikit-learn.org/stable/

# %% [markdown]
# # Examples of Scikit-learn

# %%
import sklearn
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
x = np.array([5, 15, 25, 35, 45, 55]).reshape((-1, 1))
y = np.array([5, 20, 14, 32, 22, 38])

# %%
print(x)
print(y)
# Out:
# [[ 5]
#  [15]
#  [25]
#  [35]
#  [45]
#  [55]]
# [ 5 20 14 32 22 38]

# %%
model = LinearRegression()

# %%
model.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model = LinearRegression().fit(x, y)

# %%
r_sq = model.score(x, y)
intercept, coefficients = model.intercept_, model.coef_

# %%
print(r_sq)
print(intercept)
print(coefficients)
# Out:
# 0.715875613747954
# 5.633333333333329
# [0.54]

# %%
y_pred = model.predict(x)

# %%
print(y_pred)
# Out:
# [ 8.33333333 13.73333333 19.13333333 24.53333333 29.93333333 35.33333333]

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import seaborn

# %% [markdown]
# # Basic data structures
#
# Pandas does this through two fundamental object types, both built upon NumPy arrays: the ``Series`` object, and the ``DataFrame`` object.

# %% [markdown]
# ## Series
#
# A Series is a basic holder for **one-dimensional labeled data**. It can be created much as a NumPy array is created:

# %%
a = pd.Series([0.1, 0.2, 0.3, 0.4])
a
# Out:
# 0    0.1
# 1    0.2
# 2    0.3
# 3    0.4
# dtype: float64

# %% [markdown]
# Attributes of a Series: index and values
# The series has a built-in concept of an index, which by default is the numbers 0 through N - 1

# %%
a.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
a.values
# Out:
# array([0.1, 0.2, 0.3, 0.4])

# %%
a[0]
# Out:
# 0.1

# %%
a1 = pd.Series(np.arange(4), index=['a', 'b', 'c', 'd'])
a1
# Out:
# a    0
# b    1
# c    2
# d    3
# dtype: int64

# %%
a1['c']
# Out:
# 2

# %% [markdown]
# In this way, a Series object can be thought of as similar to an ordered dictionary mapping one typed value to another typed value:

# %%
population = pd.Series({'Germany': 81.3, 'Belgium': 11.3, 'France': 64.3, 'United Kingdom': 64.9, 'Netherlands': 16.9})
population
# Out:
# Germany           81.3
# Belgium           11.3
# France            64.3
# United Kingdom    64.9
# Netherlands       16.9
# dtype: float64

# %%
population['France']
# Out:
# 64.3

# %%
population * 100
# Out:
# Germany           8130.0
# Belgium           1130.0
# France            6430.0
# United Kingdom    6490.0
# Netherlands       1690.0
# dtype: float64

# %% [markdown]
# We can index or slice the populations as expected:

# %%
population['Belgium']
# Out:
# 11.3

# %%
population['Germany':'France']
# Out:
# Germany    81.3
# Belgium    11.3
# France     64.3
# dtype: float64

# %%
population[['France', 'Netherlands']]
# Out:
# France         64.3
# Netherlands    16.9
# dtype: float64

# %%
population[population > 20]
# Out:
# Germany           81.3
# France            64.3
# United Kingdom    64.9
# dtype: float64

# %%
population / 100
# Out:
# Germany           0.813
# Belgium           0.113
# France            0.643
# United Kingdom    0.649
# Netherlands       0.169
# dtype: float64

# %%
population.mean()
# Out:
# 47.739999999999995

# %% [markdown]
# ### Alignment!
#
# Only, pay attention to **alignment**: operations between series will align on the index:

# %%
s1 = population[['Belgium', 'France']]
s2 = population[['France', 'Germany']]

# %%
s1+s2
# Out:
# Belgium      NaN
# France     128.6
# Germany      NaN
# dtype: float64

# %% [markdown]
# ## DataFrames: Multi-dimensional Data
#
# A DataFrame is a **tablular data structure** (multi-dimensional object to hold labeled data) comprised of rows and columns, akin to a spreadsheet, database table, or R's data.frame object. You can think of it as multiple Series object which share the same index.

# %% [markdown]
# One of the most common ways of creating a dataframe is from a dictionary of arrays or lists.
#
# Note that in the IPython notebook, the dataframe will display in a rich HTML view:

# %%
data = {'country': ['Belgium', 'France', 'Germany', 'Netherlands', 'United Kingdom'],
        'population': [11.3, 64.3, 81.3, 16.9, 64.9],
        'area': [30510, 671308, 357050, 41526, 244820],
        'capital': ['Brussels', 'Paris', 'Berlin', 'Amsterdam', 'London']}
countries = pd.DataFrame(data)
countries
# Out:
#           country  population    area    capital
# 0         Belgium        11.3   30510   Brussels
# 1          France        64.3  671308      Paris
# 2         Germany        81.3  357050     Berlin
# 3     Netherlands        16.9   41526  Amsterdam
# 4  United Kingdom        64.9  244820     London

# %% [markdown]
# ### Attributes of the DataFrame
#
# A DataFrame has besides a `index` attribute, also a `columns` attribute:

# %%
countries.columns
# Out:
# Index(['country', 'population', 'area', 'capital'], dtype='object')

# %%
countries.dtypes
# Out:
# country        object
# population    float64
# area            int64
# capital        object
# dtype: object

# %%
countries.info
# Out:
# <bound method DataFrame.info of           country  population    area    capital
# 0         Belgium        11.3   30510   Brussels
# 1          France        64.3  671308      Paris
# 2         Germany        81.3  357050     Berlin
# 3     Netherlands        16.9   41526  Amsterdam
# 4  United Kingdom        64.9  244820     London>

# %%
countries.values
# Out:
# array([['Belgium', 11.3, 30510, 'Brussels'],
#        ['France', 64.3, 671308, 'Paris'],
#        ['Germany', 81.3, 357050, 'Berlin'],
#        ['Netherlands', 16.9, 41526, 'Amsterdam'],
#        ['United Kingdom', 64.9, 244820, 'London']], dtype=object)

# %%
countries = countries.set_index('country')
countries
# Out:
#                 population    area    capital
# country
# Belgium               11.3   30510   Brussels
# France                64.3  671308      Paris
# Germany               81.3  357050     Berlin
# Netherlands           16.9   41526  Amsterdam
# United Kingdom        64.9  244820     London

# %%
countries['area']
# Out:
# country
# Belgium            30510
# France            671308
# Germany           357050
# Netherlands        41526
# United Kingdom    244820
# Name: area, dtype: int64

# %% [markdown]
# As you play around with DataFrames, you'll notice that many operations which work on NumPy arrays will also work on dataframes.
#
# Let's compute density of each country:

# %%
countries['population']*1000000 / countries['area']
# Out:
# country
# Belgium           370.370370
# France             95.783158
# Germany           227.699202
# Netherlands       406.973944
# United Kingdom    265.092721
# dtype: float64

# %% [markdown]
# Adding a new column to the dataframe is very simple:

# %%
countries['density'] = countries['population']*1000000 / countries['area']
countries
# Out:
#                 population    area    capital     density
# country
# Belgium               11.3   30510   Brussels  370.370370
# France                64.3  671308      Paris   95.783158
# Germany               81.3  357050     Berlin  227.699202
# Netherlands           16.9   41526  Amsterdam  406.973944
# United Kingdom        64.9  244820     London  265.092721

# %%
countries[countries['density'] > 300]
# Out:
#              population   area    capital     density
# country
# Belgium            11.3  30510   Brussels  370.370370
# Netherlands        16.9  41526  Amsterdam  406.973944

# %% [markdown]
# And we can do things like sorting the items in the array, and indexing to take the first two rows:

# %%
countries.sort_values(by='density', ascending=False)
# Out:
#                 population    area    capital     density
# country
# Netherlands           16.9   41526  Amsterdam  406.973944
# Belgium               11.3   30510   Brussels  370.370370
# United Kingdom        64.9  244820     London  265.092721
# Germany               81.3  357050     Berlin  227.699202
# France                64.3  671308      Paris   95.783158

# %% [markdown]
# One useful method to use is the ``describe`` method, which computes summary statistics for each column:

# %%
countries.describe()
# Out:
#        population           area     density
# count    5.000000       5.000000    5.000000
# mean    47.740000  269042.800000  273.183879
# std     31.519645  264012.827994  123.440607
# min     11.300000   30510.000000   95.783158
# 25%     16.900000   41526.000000  227.699202
# 50%     64.300000  244820.000000  265.092721
# 75%     64.900000  357050.000000  370.370370
# max     81.300000  671308.000000  406.973944

# %% [markdown]
# The `plot` method can be used to quickly visualize the data in different ways:

# %%
countries.plot()

# %%
countries['population'].plot(kind='bar')

# %%
countries.plot(kind='scatter', x='population', y='area')

# %% [markdown]
# The available plotting types: ‘line’ (default), ‘bar’, ‘barh’, ‘hist’, ‘box’ , ‘kde’, ‘area’, ‘pie’, ‘scatter’, ‘hexbin’.

# %%
##countries = countries.drop(['density'], axis=1)

# %% [markdown]
# ## Selecting data
#
# One of pandas' basic features is the labeling of rows and columns, but this makes indexing also a bit more complex compared to numpy. We now have to distuinguish between:
#
# - selection by label
# - selection by position.

# %% [markdown]
# For a DataFrame, basic indexing selects the columns.
#
# Selecting a single column:

# %%
countries['area']
# Out:
# country
# Belgium            30510
# France            671308
# Germany           357050
# Netherlands        41526
# United Kingdom    244820
# Name: area, dtype: int64

# %% [markdown]
# or multiple columns:

# %%
countries[['area', 'density']]
# Out:
#                   area     density
# country
# Belgium          30510  370.370370
# France          671308   95.783158
# Germany         357050  227.699202
# Netherlands      41526  406.973944
# United Kingdom  244820  265.092721

# %% [markdown]
# But, slicing accesses the rows:

# %%
countries['France':'Netherlands']
# Out:
#              population    area    capital     density
# country
# France             64.3  671308      Paris   95.783158
# Germany            81.3  357050     Berlin  227.699202
# Netherlands        16.9   41526  Amsterdam  406.973944

# %% [markdown]
# For more advanced indexing, you have some extra attributes:
#
# * `loc`: selection by label
# * `iloc`: selection by position

# %%
countries.loc['Germany', 'area']
# Out:
# 357050

# %%
countries.loc['France':'Netherlands', :]
# Out:
#              population    area    capital     density
# country
# France             64.3  671308      Paris   95.783158
# Germany            81.3  357050     Berlin  227.699202
# Netherlands        16.9   41526  Amsterdam  406.973944

# %%
countries.loc[countries['density']>300, ['capital', 'population']]
# Out:
#                capital  population
# country
# Belgium       Brussels        11.3
# Netherlands  Amsterdam        16.9

# %% [markdown]
# Selecting by position with `iloc` works similar as indexing numpy arrays:

# %%
countries.iloc[0:2,1:3]
# Out:
#            area   capital
# country
# Belgium   30510  Brussels
# France   671308     Paris

# %% [markdown]
# The different indexing methods can also be used to assign data:

# %%
countries.loc['Belgium':'Germany', 'population'] = 10

# %%
countries
# Out:
#                 population    area    capital     density
# country
# Belgium               10.0   30510   Brussels  370.370370
# France                10.0  671308      Paris   95.783158
# Germany               10.0  357050     Berlin  227.699202
# Netherlands           16.9   41526  Amsterdam  406.973944
# United Kingdom        64.9  244820     London  265.092721

# %% [markdown]
# # Data Visualization in-class

# %%
#define a style
plt.style.use('classic')
# create an array of 100 numbers from 0 to 10
x = np.linspace(0, 10, 100)
#prepare a figure and plot
fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--');
#plot it
plt.show()

# %%
#define a style
plt.style.use('classic')

# create an array of 100 numbers from 0 to 10
x = np.linspace(0, 10, 100)
#prepare a figure and plot
plt.figure()  # create a plot figure

# create the first of two panels and set current axis
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));
#show it
plt.show()

# %%
# First create a grid of plots
# ax will be an array of two Axes objects 
fig, ax = plt.subplots(2)
# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x)) 
ax[1].plot(x, np.cos(x)); #plot it
plt.show()

# %%
plt.style.use('seaborn-whitegrid') 

fig = plt.figure()
ax = plt.axes()
plt.plot(x, np.sin(x - 0), color='blue')
plt.plot(x, np.sin(x - 1), color='g')
plt.plot(x, np.sin(x - 2), color='0.75')
plt.plot(x, np.sin(x - 3), color='#FFDD44') # Hex code (RRGGBB from 00 to FF) plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 to 1
plt.plot(x, np.sin(x - 5), color='chartreuse') # all HTML color names supported plt.show()

# %%
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 100) 
plt.plot(x, x + 0, linestyle='solid') 
plt.plot(x, x + 1, linestyle='dashed') 
plt.plot(x, x + 2, linestyle='dashdot') 
plt.plot(x, x + 3, linestyle='dotted');
# OR For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-') # solid 
plt.plot(x, x + 5, linestyle='--') # dashed 
plt.plot(x, x + 6, linestyle='-.') # dashdot 
plt.plot(x, x + 7, linestyle=':'); # dotted 
plt.show()

# %%
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 100)
plt.plot(x, x + 0, '-g') # solid green 
plt.plot(x, x + 1, '--c') # dashed cyan 
plt.plot(x, x + 2, '-.k') # dashdot black 
plt.plot(x, x + 3, ':r'); # dotted red 
plt.show()

# %%
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.xlim(-1, 11) 
plt.ylim(-1.5, 1.5) 
plt.show()

# %%
plt.plot(x, np.sin(x)) 
plt.title("A Sine Curve") 
plt.xlabel("x") 
plt.ylabel("sin(x)");

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

rng = np.random.RandomState(20)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
             label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 1.8);
plt.show()

# %%
a=np.random.rand(5)
a
# Out:
# array([0.75762947, 0.20113428, 0.47633051, 0.06132372, 0.32133785])

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

plt.contour(X, Y, Z, colors='black');
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

plt.contour(X, Y, Z, 20, cmap='RdGy')
plt.show()

# %%
contours = plt.contour(X, Y, Z, 3, colors='black') 
plt.clabel(contours, inline=True, fontsize=8)
plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower', cmap='RdGy', alpha=0.5)
plt.colorbar();

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

data = np.random.randn(1000)
plt.hist(data)
plt.show()

plt.hist(data, bins=30, density=True, alpha=0.5,
         histtype='stepfilled', color='steelblue',
         edgecolor='none')
plt.show()

x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)
kwargs = dict(histtype='stepfilled', alpha=0.3, density=True, bins=40)
plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
plt.show()

# %%
from scipy.stats import gaussian_kde
import numpy as np
import matplotlib.pyplot as plt

mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T

# fit an array of size [Ndim, Nsamples]
data = np.vstack([x, y])
kde = gaussian_kde(data)

# evaluate on a regular grid
xgrid = np.linspace(-3.5, 3.5, 40)
ygrid = np.linspace(-6, 6, 40)
Xgrid, Ygrid = np.meshgrid(xgrid, ygrid)
Z = kde.evaluate(np.vstack([Xgrid.ravel(), Ygrid.ravel()]))

# Plot the result as an image
plt.imshow(Z.reshape(Xgrid.shape),
           origin='lower', aspect='auto',
           extent=[-3.5, 3.5, -6, 6],
           cmap='Blues')
cb = plt.colorbar()
cb.set_label("density")

mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T 
plt.hist2d(x, y, bins=30, cmap='Blues')
cb = plt.colorbar()
cb.set_label('counts in bin')
plt.show()
